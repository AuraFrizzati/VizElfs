# %% [markdown]
# # Explore Level 3 data

# %%
# conda install -n geopandas_env ipykernel --update-deps --force-reinstall
# conda install openpyxl
# conda activate geopandas_env
import pandas as pd

# %%
df_l3 = pd.read_excel("data/Level_3.xlsx")

# %%
df_l3.head()
# Out:
#   small_area co-benefit_type     damage_pathway damage_type      2025  \
# 0  E01000001     air_quality  reduced_mortality      health  0.003336
# 1  E01000001     air_quality            society  non-health  0.000039
# 2  E01000001      congestion         time_saved  non-health  0.005570
# 3  E01000001        dampness                NHS  non-health  0.000000
# 4  E01000001        dampness               QALY      health  0.000000
#
#        2026          2027          2028          2029          2030  ...  \
# 0  0.003663  6.917033e-03  8.674610e-03  1.085301e-02  1.408742e-02  ...
# 1  0.000043  8.140000e-05  1.020450e-04  1.276710e-04  1.657200e-04  ...
# 2  0.009543  1.191381e-02  1.324733e-02  1.365541e-02  1.479793e-02  ...
# 3  0.000000  1.260000e-05  1.240000e-05  1.240000e-05  2.410000e-06  ...
# 4  0.000000  3.070000e-07  3.050000e-07  3.030000e-07  5.910000e-08  ...
#
#            2042          2043          2044          2045          2046  \
# 0  6.968484e-02  7.270200e-02  7.526418e-02  7.737418e-02  7.860485e-02
# 1  8.197480e-04  8.552410e-04  8.853820e-04  9.102030e-04  9.246800e-04
# 2 -2.996094e-02 -3.209987e-02 -3.437791e-02 -3.693888e-02 -4.099173e-02
# 3  2.970000e-05  3.320000e-05  3.290000e-05  3.200000e-05  3.180000e-05
# 4  7.260000e-07  8.120000e-07  8.060000e-07  7.830000e-07  7.780000e-07
#
#            2047          2048          2049          2050       sum
# 0  7.868850e-02  7.817872e-02  7.763434e-02  7.710436e-02  1.201945
# 1  9.256640e-04  9.196670e-04  9.132640e-04  9.070290e-04  0.014139
# 2 -4.281875e-02 -4.471182e-02 -4.611941e-02 -4.897514e-02 -0.369011
# 3  3.150000e-05  3.150000e-05  3.130000e-05  3.110000e-05  0.000504
# 4  7.720000e-07  7.710000e-07  7.650000e-07  7.610000e-07  0.000012
#
# [5 rows x 31 columns]

# %%
df_lkup = pd.read_excel("data/lookups.xlsx")

# %%
df_lkup.head()
# Out:
#   small_area  population  households       local_authority  Unnamed: 4  \
# 0  E01000001        1721         838        City of London         NaN
# 1  E01000002        1608         824        City of London         NaN
# 2  E01000003        1826        1017        City of London         NaN
# 3  E01000005        1605         480        City of London         NaN
# 4  E01000006        1833         554  Barking and Dagenham         NaN
#
#       nation
# 0  Eng/Wales
# 1  Eng/Wales
# 2  Eng/Wales
# 3  Eng/Wales
# 4  Eng/Wales

# %%
df_lkup = df_lkup.drop('Unnamed: 4', axis=1)
df_lkup.head()
# Out:
#   small_area  population  households       local_authority     nation
# 0  E01000001        1721         838        City of London  Eng/Wales
# 1  E01000002        1608         824        City of London  Eng/Wales
# 2  E01000003        1826        1017        City of London  Eng/Wales
# 3  E01000005        1605         480        City of London  Eng/Wales
# 4  E01000006        1833         554  Barking and Dagenham  Eng/Wales

# %% [markdown]
# ## Generating a Cardiff LSOA table

# %%
df_lkupCardiff = df_lkup[df_lkup['local_authority'] == "Cardiff"]

# %%
df_lkupCardiff.head()
# Out:
#       small_area  population  households local_authority     nation
# 46097  W01001694        2064         885         Cardiff  Eng/Wales
# 46098  W01001695        4906         747         Cardiff  Eng/Wales
# 46099  W01001696        1581         669         Cardiff  Eng/Wales
# 46100  W01001697        2024         864         Cardiff  Eng/Wales
# 46101  W01001698        2148         947         Cardiff  Eng/Wales

# %%
df_l3Car = df_l3[
    df_l3['small_area'].isin(df_lkupCardiff['small_area'])
]

df_l3Car.head()
# Out:
#        small_area co-benefit_type     damage_pathway damage_type      2025  \
# 921940  W01001694     air_quality  reduced_mortality      health  0.003359
# 921941  W01001694     air_quality            society  non-health  0.000039
# 921942  W01001694      congestion         time_saved  non-health  0.000000
# 921943  W01001694        dampness                NHS  non-health  0.000000
# 921944  W01001694        dampness               QALY      health  0.000000
#
#                 2026          2027      2028      2029      2030  ...  \
# 921940  5.408322e-03  6.949793e-03  0.008954  0.011502  0.015201  ...
# 921941  6.360000e-05  8.180000e-05  0.000105  0.000135  0.000179  ...
# 921942  0.000000e+00  0.000000e+00  0.000000  0.000000  0.000000  ...
# 921943  7.190000e-08  1.270000e-07  0.000173  0.000173  0.000055  ...
# 921944  1.760000e-09  3.100000e-09  0.000004  0.000004  0.000001  ...
#
#             2042      2043      2044      2045      2046      2047      2048  \
# 921940  0.083768  0.087481  0.090648  0.093248  0.094787  0.094953  0.094402
# 921941  0.000985  0.001029  0.001066  0.001097  0.001115  0.001117  0.001111
# 921942  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 921943  0.000291  0.000290  0.000288  0.000286  0.000284  0.000282  0.000280
# 921944  0.000007  0.000007  0.000007  0.000007  0.000007  0.000007  0.000007
#
#             2049      2050       sum
# 921940  0.093800  0.093225  1.432637
# 921941  0.001103  0.001097  0.016853
# 921942  0.000000  0.000000  0.000000
# 921943  0.000278  0.000276  0.004798
# 921944  0.000007  0.000007  0.000117
#
# [5 rows x 31 columns]

# %%
import geopandas as gpd

shapefile_path = "data/shapefile/small_areas_british_grid.shp"

lsoa_gdf = gpd.read_file(shapefile_path)

print(lsoa_gdf.head())
print(lsoa_gdf.crs)
# Out:
#   small_area                                           geometry
# 0  N20000001  POLYGON ((133996.914 553603.376, 133988.252 55...
# 1  N20000002  POLYGON ((137865.858 549642.6, 137859.499 5496...
# 2  N20000003  POLYGON ((119675.619 552886.698, 119676.791 55...
# 3  N20000004  POLYGON ((125776.464 552336.061, 125785.354 55...
# 4  N20000005  POLYGON ((137865.858 549642.6, 137874.822 5496...
# EPSG:27700

# %%
lsoa_gdfCar = lsoa_gdf[
    lsoa_gdf['small_area'].isin(df_lkupCardiff['small_area'])
]

lsoa_gdfCar.head()
# Out:
#       small_area                                           geometry
# 39123  W01001694  POLYGON ((319914.257 177185.757, 319989.874 17...
# 39124  W01001695  POLYGON ((319113.134 176156.499, 318744.193 17...
# 39125  W01001696  POLYGON ((319522.201 176874.91, 319506.633 176...
# 39126  W01001697  POLYGON ((320769.411 177854.192, 320372.594 17...
# 39127  W01001698  POLYGON ((319942.001 177578.5, 320106.341 1775...

# %%
lsoa_gdfCar = lsoa_gdfCar.to_crs(epsg=4326)

# %%
lsoa_gdfCar.plot(edgecolor="black", facecolor="none")
# Out:
# <Axes: >

# %%
df_air_2025 = df_l3Car[
    df_l3Car['co-benefit_type'] == 'air_quality'
]

df_air_2025.head()
# Out:
#        small_area co-benefit_type     damage_pathway damage_type      2025  \
# 921940  W01001694     air_quality  reduced_mortality      health  0.003359
# 921941  W01001694     air_quality            society  non-health  0.000039
# 921960  W01001695     air_quality  reduced_mortality      health  0.007985
# 921961  W01001695     air_quality            society  non-health  0.000094
# 921980  W01001696     air_quality  reduced_mortality      health  0.003254
#
#             2026      2027      2028      2029      2030  ...      2042  \
# 921940  0.005408  0.006950  0.008954  0.011502  0.015201  ...  0.083768
# 921941  0.000064  0.000082  0.000105  0.000135  0.000179  ...  0.000985
# 921960  0.012855  0.016519  0.021284  0.027339  0.036132  ...  0.199111
# 921961  0.000151  0.000194  0.000250  0.000322  0.000425  ...  0.002342
# 921980  0.004143  0.005323  0.006859  0.008810  0.011644  ...  0.064165
#
#             2043      2044      2045      2046      2047      2048      2049  \
# 921940  0.087481  0.090648  0.093248  0.094787  0.094953  0.094402  0.093800
# 921941  0.001029  0.001066  0.001097  0.001115  0.001117  0.001111  0.001103
# 921960  0.207936  0.215464  0.221644  0.225304  0.225698  0.224387  0.222957
# 921961  0.002446  0.002535  0.002607  0.002650  0.002655  0.002640  0.002623
# 921980  0.067009  0.069435  0.071427  0.072606  0.072733  0.072311  0.071850
#
#             2050       sum
# 921940  0.093225  1.432637
# 921941  0.001097  0.016853
# 921960  0.221590  3.405289
# 921961  0.002607  0.040059
# 921980  0.071409  1.098064
#
# [5 rows x 31 columns]

# %%
df_air_2025.columns
# Out:
# Index([     'small_area', 'co-benefit_type',  'damage_pathway',
#            'damage_type',              2025,              2026,
#                     2027,              2028,              2029,
#                     2030,              2031,              2032,
#                     2033,              2034,              2035,
#                     2036,              2037,              2038,
#                     2039,              2040,              2041,
#                     2042,              2043,              2044,
#                     2045,              2046,              2047,
#                     2048,              2049,              2050,
#                    'sum'],
#       dtype='object')

# %%
import pandas as pd

wimd = pd.read_excel(
    "/Users/owenevans/VizElfs/data/wimd-2025-index-and-domain-ranks-by-small-area.ods",
    sheet_name = "Deciles_quintiles_quartiles",
    skiprows=3,
    engine="odf"
)


wimd.head()
# Out:
#    LSOA code LSOA name (Eng) Local Authority name (Eng)  \
# 0  W01000003     Amlwch Port           Isle of Anglesey
# 1  W01000004    Amlwch Rural           Isle of Anglesey
# 2  W01000005       Beaumaris           Isle of Anglesey
# 3  W01000006       Bodffordd           Isle of Anglesey
# 4  W01000007        Bodorgan           Isle of Anglesey
#
#    WIMD 2025 overall rank   WIMD 2025 overall decile  \
# 0                      570                         3
# 1                     1132                         6
# 2                      676                         4
# 3                      991                         6
# 4                     1026                         6
#
#    WIMD 2025 overall quintile  WIMD 2025 overall quartile  \
# 0                           2                           2
# 1                           3                           3
# 2                           2                           2
# 3                           3                           3
# 4                           3                           3
#
#    WIMD 2025 overall deprivation group
# 0                                    3
# 1                                    5
# 2                                    4
# 3                                    5
# 4                                    5

# %%
# Merging main table + lookup + wimd
df_l3Car_lookup = pd.merge(df_l3Car, df_lkupCardiff, how='left', on=['small_area'])
df_l3Car_lookup.head()
#df_l3Car_lookup.shape
df_l3Car_lookup_wimd= pd.merge(df_l3Car_lookup, wimd, how='left', left_on=['small_area'], right_on=['LSOA code'])
df_l3Car_lookup_wimd.head()
# Out:
#   small_area co-benefit_type     damage_pathway damage_type      2025  \
# 0  W01001694     air_quality  reduced_mortality      health  0.003359
# 1  W01001694     air_quality            society  non-health  0.000039
# 2  W01001694      congestion         time_saved  non-health  0.000000
# 3  W01001694        dampness                NHS  non-health  0.000000
# 4  W01001694        dampness               QALY      health  0.000000
#
#            2026          2027      2028      2029      2030  ...  \
# 0  5.408322e-03  6.949793e-03  0.008954  0.011502  0.015201  ...
# 1  6.360000e-05  8.180000e-05  0.000105  0.000135  0.000179  ...
# 2  0.000000e+00  0.000000e+00  0.000000  0.000000  0.000000  ...
# 3  7.190000e-08  1.270000e-07  0.000173  0.000173  0.000055  ...
# 4  1.760000e-09  3.100000e-09  0.000004  0.000004  0.000001  ...
#
#    local_authority     nation  LSOA code  LSOA name (Eng)  \
# 0          Cardiff  Eng/Wales  W01001694      Adamsdown 1
# 1          Cardiff  Eng/Wales  W01001694      Adamsdown 1
# 2          Cardiff  Eng/Wales  W01001694      Adamsdown 1
# 3          Cardiff  Eng/Wales  W01001694      Adamsdown 1
# 4          Cardiff  Eng/Wales  W01001694      Adamsdown 1
#
#    Local Authority name (Eng)  WIMD 2025 overall rank   \
# 0                     Cardiff                      189
# 1                     Cardiff                      189
# 2                     Cardiff                      189
# 3                     Cardiff                      189
# 4                     Cardiff                      189
#
#    WIMD 2025 overall decile  WIMD 2025 overall quintile  \
# 0                         1                           1
# 1                         1                           1
# 2                         1                           1
# 3                         1                           1
# 4                         1                           1
#
#    WIMD 2025 overall quartile  WIMD 2025 overall deprivation group
# 0                           1                                    1
# 1                           1                                    1
# 2                           1                                    1
# 3                           1                                    1
# 4                           1                                    1
#
# [5 rows x 43 columns]

# %%
df_l3Car_lookup_wimd.drop(
    columns=['small_area','local_authority','nation','Local Authority name (Eng)','WIMD 2025 overall quartile','WIMD 2025 overall deprivation group'],
    inplace=True
)

df_l3Car_lookup_wimd.head()
# Out:
#   co-benefit_type     damage_pathway damage_type      2025          2026  \
# 0     air_quality  reduced_mortality      health  0.003359  5.408322e-03
# 1     air_quality            society  non-health  0.000039  6.360000e-05
# 2      congestion         time_saved  non-health  0.000000  0.000000e+00
# 3        dampness                NHS  non-health  0.000000  7.190000e-08
# 4        dampness               QALY      health  0.000000  1.760000e-09
#
#            2027      2028      2029      2030          2031  ...      2049  \
# 0  6.949793e-03  0.008954  0.011502  0.015201  1.941414e-02  ...  0.093800
# 1  8.180000e-05  0.000105  0.000135  0.000179  2.283810e-04  ...  0.001103
# 2  0.000000e+00  0.000000  0.000000  0.000000  0.000000e+00  ...  0.000000
# 3  1.270000e-07  0.000173  0.000173  0.000055  8.900000e-06  ...  0.000278
# 4  3.100000e-09  0.000004  0.000004  0.000001  2.180000e-07  ...  0.000007
#
#        2050       sum  population  households  LSOA code  LSOA name (Eng)  \
# 0  0.093225  1.432637        2064         885  W01001694      Adamsdown 1
# 1  0.001097  0.016853        2064         885  W01001694      Adamsdown 1
# 2  0.000000  0.000000        2064         885  W01001694      Adamsdown 1
# 3  0.000276  0.004798        2064         885  W01001694      Adamsdown 1
# 4  0.000007  0.000117        2064         885  W01001694      Adamsdown 1
#
#    WIMD 2025 overall rank   WIMD 2025 overall decile  \
# 0                      189                         1
# 1                      189                         1
# 2                      189                         1
# 3                      189                         1
# 4                      189                         1
#
#    WIMD 2025 overall quintile
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
#
# [5 rows x 37 columns]
